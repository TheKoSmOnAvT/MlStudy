# %%
#71_36.csv

# %%
import csv

array = []
with open('71_36.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for rows in spamreader:
        for row in rows:
            ar = []
            for num in row.split(','):
                ar.append(float(num))          
            array.append(ar)

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn import datasets
import matplotlib
import matplotlib.pyplot as plt

# %%
len(array)
# Out:
# 60

# %%
#Создание объекта класса PCA. В качестве параметров выступает количество ГК и метод оптимизации
pca = PCA(n_components=10, svd_solver='full') 
X_transformed = pca.fit(array).transform(array) #X_transformed -- ndarray объектов, где каждый объект описывается n ГК

# %%
X_transformed[0]
# Out:
# array([ 40.97493191,  -4.5220835 , -24.57298682,   4.19385484,
#         -4.06919108,   0.13629479,   1.23587937,   2.77425808,
#          0.51012927,   0.07867333])

# %%
explained_variance = np.round(np.cumsum(pca.explained_variance_ratio_),10)
explained_variance
# Out:
# array([0.41210653, 0.71626519, 0.85863051, 0.94881431, 0.99414948,
#        0.99565438, 0.99698355, 0.99818674, 0.99928317, 1.        ])

# %%
plt.figure(figsize=(15, 15))
plt.plot(np.arange(10), explained_variance)#, ls = '-'
plt.grid()
